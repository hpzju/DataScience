# %% [markdown]
# # Pandas with seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,8))
sns.set_style()
sns.despine()

# %%
sns.set_context()

# %%
sns.get_dataset_names()
# Out:
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
df1 = sns.load_dataset('planets')
df1
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %% [markdown]
# ## distplot

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(df['tip'], bins=20)

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.distplot(df['petal_length'])
plt.show()

# %%
sns.distplot(df['petal_length'], kde=False)
plt.show()

# %%
sns.distplot(df['petal_length'], hist=False)
plt.show()

# %% [markdown]
# ## jointplot

# %%
df = sns.load_dataset('iris')

# %%
sns.jointplot(x = 'petal_length', y = 'petal_width', data=df)
sns.jointplot(x = 'petal_length', y = 'petal_width', data=df, kind='hex')
sns.jointplot(x = 'petal_length', y = 'petal_width', data=df, kind='reg')
plt.show()

# %% [markdown]
# ## pairplot

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.set_style("ticks")
sns.pairplot(df, hue="species", diag_kind="kde",
            kind="scatter", palette="husl")
plt.show()

# %% [markdown]
# ## rugplot

# %%
df = sns.load_dataset('iris')

# %%
sns.rugplot(df['sepal_length'] )
sns.rugplot(df['sepal_width'] )

# %% [markdown]
# ## stripplot

# %%
df = sns.load_dataset('iris')

# %%
sns.stripplot(x="species", y="petal_length", data=df)
plt.show()

# %% [markdown]
# ## violinplot

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='day', y = 'total_bill', data=df)
plt.show()

# %%
sns.violinplot(x='day', y = 'total_bill', 
               hue='sex', data=df)
plt.show()

# %% [markdown]
# ## swarmplot

# %%
df = sns.load_dataset('tips')
df

# %%
sns.swarmplot(x='day', y = 'total_bill', 
               hue='sex', data=df)
plt.show()

# %% [markdown]
# ## barplot

# %%
df = sns.load_dataset('titanic')
sns.barplot(x='sex', y='survived',
           hue='class', data=df)
plt.show()

# %% [markdown]
# ## catplot

# %%
df = sns.load_dataset('tips')
df

# %%
sns.catplot(x='day', y = 'total_bill', 
               hue='sex', data=df, kind='boxen')

# %% [markdown]
# ## countplot

# %%
sns.countplot(x='class', data=df, palette="Blues")
plt.show()

# %% [markdown]
# ## pointplot

# %%
sns.pointplot(x='sex', data=df, y="survived", hue='class')
plt.show()

# %% [markdown]
# ## boxplot

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(data= df, x='size', y='total_bill', hue='sex')
plt.show()

# %%
sns.boxplot(data= df, orient='v')
plt.show()

# %% [markdown]
# ## heatmap

# %%
df = sns.load_dataset('tips')
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(8,4))
sns.heatmap(df.corr(), annot=True, center=0, vmin=0, vmax=1, fmt=".2f", linewidths=.3)

# %%
df_tips = sns.load_dataset('tips')
df_flights = sns.load_dataset('flights')

# %%
df_tips.head(), df_flights.head()
# Out:
# (   total_bill   tip     sex smoker  day    time  size
#  0       16.99  1.01  Female     No  Sun  Dinner     2
#  1       10.34  1.66    Male     No  Sun  Dinner     3
#  2       21.01  3.50    Male     No  Sun  Dinner     3
#  3       23.68  3.31    Male     No  Sun  Dinner     2
#  4       24.59  3.61  Female     No  Sun  Dinner     4,
#     year     month  passengers
#  0  1949   January         112
#  1  1949  February         118
#  2  1949     March         132
#  3  1949     April         129
#  4  1949       May         121)

# %% [markdown]
# ## clustermap

# %%
plt.figure(figsize=(12,12))
sns.clustermap(df_flights.pivot_table(index='month', columns='year', values='passengers'), annot=True, fmt='.2f')

# %% [markdown]
# ## FacetGrid

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(df, col='size', row='day')
g.map(sns.distplot, 'total_bill')

# %%
g = sns.FacetGrid(df, col='size', row='day')
g.map(plt.scatter, 'tip', 'total_bill')

# %% [markdown]
# ## PairGrid

# %%
df = sns.load_dataset('iris')

# %%
sns.pairplot(df)

# %%
g = sns.PairGrid(df)
g.map(plt.scatter)

# %%
g = sns.PairGrid(df)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %% [markdown]
# ## kdeplot

# %% [markdown]
# ## lmplot

# %%
df = sns.load_dataset('tips')
plt.figure(figsize=(8,8))

sns.lmplot(x='tip', y= 'total_bill', hue='sex', data=df)

# %%
df = sns.load_dataset('tips')
plt.figure(figsize=(8,8))

sns.lmplot(x='tip', y= 'total_bill', hue='sex', row='day', col='time', data=df)

# %% [markdown]
# ## regplot

# %%
f, ax = plt.subplots(figsize=(5, 6))
df = sns.load_dataset('iris')
sns.regplot(x='sepal_length',
           y= 'petal_length',
           data=df, ax=ax)
plt.show()

# %% [markdown]
# ## lmplot: linear model

# %%
tips = sns.load_dataset('tips')
sns.lmplot(x='total_bill', y ='tip', data=tips,
          hue='sex', palette='Set1')
plt.show()

# %%
sns.lmplot(x='total_bill', y ='tip', data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data= tips, row='sex')
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data= tips, col='sex')
plt.show()

# %% [markdown]
# # Pandas with Plotly

# %% [markdown]
# >
# >  ```bash
# >    conda install -c plotly plotly-geo
# >    conda install -c plotly chart-studio
# >    conda install -c plotly plotly-orca psutil requests
# >  ```

# %%
import plotly

# %%
plotly.__version__
# Out:
# '4.1.1'

# %% [markdown]
# ## Plotly 4.x

# %%
import pandas as pd
import numpy as np
import plotly.io as pio
import plotly.graph_objects as go
import plotly.express as px

# %%
pio.renderers, pio.templates
# Out:
# (Renderers configuration
#  -----------------------
#      Default renderer: 'plotly_mimetype+notebook'
#      Available renderers:
#          ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#           'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#           'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#           'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#           'iframe_connected', 'sphinx_gallery'], Templates configuration
#  -----------------------
#      Default template: 'plotly'
#      Available templates:
#          ['ggplot2', 'seaborn', 'plotly', 'plotly_white', 'plotly_dark',
#           'presentation', 'xgridoff', 'none'])

# %%
plotly_template = pio.templates["plotly"]
plotly_template.layout
# Out:
# Layout({
#     'annotationdefaults': {'arrowcolor': '#2a3f5f', 'arrowhead': 0, 'arrowwidth': 1},
#     'colorscale': {'diverging': [[0, '#8e0152'], [0.1, '#c51b7d'], [0.2,
#                                  '#de77ae'], [0.3, '#f1b6da'], [0.4, '#fde0ef'],
#                                  [0.5, '#f7f7f7'], [0.6, '#e6f5d0'], [0.7,
#                                  '#b8e186'], [0.8, '#7fbc41'], [0.9, '#4d9221'],
#                                  [1, '#276419']],
#                    'sequential': [[0.0, '#0d0887'], [0.1111111111111111,
#                                   '#46039f'], [0.2222222222222222, '#7201a8'],
#                                   [0.3333333333333333, '#9c179e'],
#                                   [0.4444444444444444, '#bd3786'],
#                                   [0.5555555555555556, '#d8576b'],
#                                   [0.6666666666666666, '#ed7953'],
#                                   [0.7777777777777778, '#fb9f3a'],
# ...

# %%
gapminder = px.data.gapminder()
gapminder_2007 = gapminder.query("year==2007")

for template in ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "none"]:
    fig = px.scatter(gapminder_2007,
                     x="gdpPercap", y="lifeExp", size="pop", color="continent",
                     log_x=True, size_max=60,
                     template=template, title=f"Gapminder 2007: {template} theme" )
    print(f"Gapminder 2007: {template} theme")
    fig.write_html(f'IMG/Gapminder_2007_{template}_theme.html',auto_open=True)
# Out:
# Gapminder 2007: plotly theme
# Gapminder 2007: plotly_white theme
# Gapminder 2007: plotly_dark theme
# Gapminder 2007: ggplot2 theme
# Gapminder 2007: seaborn theme
# Gapminder 2007: none theme

# %% [markdown]
# ### Display Figure
#   - Using the renderers framework in the context of a script or notebook
#   - Using Dash in a web app context
#   - Using a FigureWidget in an ipywidgets context

# %% [markdown]
# #### Render with HTML

# %%
import plotly.graph_objects as go
fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
fig.write_html('IMG/plotly_helloworld.html', auto_open=True)

# %% [markdown]
# #### Render with Jupyter iframe

# %%
import plotly.graph_objects as go
fig = go.Figure(data=go.Bar(y=[2, 3, 1]))
fig.show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_8.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# #### Render with FigureWidget

# %%
import plotly.graph_objects as go

f = go.FigureWidget(data=go.Bar(y=[2, 3, 1]))
f
# Out:
# FigureWidget({
#     'data': [{'type': 'bar', 'uid': 'a11d048a-4067-458e-a996-434e7cd886a1', 'y': [2, 3, 1]}],
#  …

# %%
import ipywidgets
ipywidgets.IntSlider()
# Out:
# IntSlider(value=0)

# %% [markdown]
# #### Render with png

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Bar(y=[2, 1, 3])],
    layout_title_text="A Figure Displayed with the 'png' Renderer"
)
fig.show(renderer="png", width=800, height=300)

# %% [markdown]
# #### Exporting as image

# %%
import plotly.graph_objects as go
import numpy as np
np.random.seed(1)

N = 100
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
sz = np.random.rand(N) * 30

fig = go.Figure()
fig.add_trace(go.Scatter(
    x=x,
    y=y,
    mode="markers",
    marker=go.scatter.Marker(
        size=sz,
        color=colors,
        opacity=0.6,
        colorscale="Viridis"
    )
))

fig.write_image('IMG/export.png', width=1024, height=600, scale=1.5)

# %% [markdown]
# #### Render with iframe

# %%
from plotly.subplots import make_subplots
fig = make_subplots(rows=1, cols=2)
fig.add_trace(go.Scatter(y=[4, 2, 1], mode="lines"), row=1, col=1)
fig.add_trace(go.Bar(y=[2, 1, 3]), row=1, col=2)
fig.write_html('IMG/plotly_subplot.html', auto_open=True)

# %% [markdown]
# ### Plotly Express

# %% [markdown]
# - https://plot.ly/python/plotly-express/

# %%
import plotly.express as px
print(px.data.iris.__doc__)
px.data.iris().head()
# Out:
#     Each row represents a flower.
#
#     https://en.wikipedia.org/wiki/Iris_flower_data_set
#
#     Returns:
#         A `pandas.DataFrame` with 150 rows and the following columns: `['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species',
#        'species_id']`.
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %% [markdown]
# #### scatter plot

# %%
import plotly.express as px
iris = px.data.iris()
fig = px.scatter(iris, x="sepal_width", y="sepal_length", color="species", marginal_y="violin",
           marginal_x="box", trendline="ols")
fig.write_html(f'IMG/scatter_iris.html',auto_open=True)
# Out:
# C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning:
#
# Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.

# %%
import plotly.express as px
tips = px.data.tips()
fig = px.scatter(tips, x="total_bill", y="tip", facet_row="time", facet_col="day", color="smoker", trendline="ols",
          category_orders={"day": ["Thur", "Fri", "Sat", "Sun"], "time": ["Lunch", "Dinner"]})
fig.write_html(f'IMG/scatter_tips.html',auto_open=True)

# %%
import plotly.express as px
iris = px.data.iris()
fig = px.scatter_matrix(iris, dimensions=["sepal_width", "sepal_length", "petal_width", "petal_length"], color="species")
fig.write_html(f'IMG/scatter_matrix_iris.html',auto_open=True)

# %% [markdown]
# #### maps

# %%
import plotly.express as px
px.set_mapbox_access_token(open(".mapbox_token").read())
carshare = px.data.carshare()
fig = px.scatter_mapbox(carshare, lat="centroid_lat", lon="centroid_lon",     color="peak_hour", size="car_hours",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10)
fig.write_html(f'IMG/scatter_mpabox_carshare.html',auto_open=True)

# %%
import plotly.express as px
gapminder = px.data.gapminder()
fig = px.scatter_geo(gapminder, locations="iso_alpha", color="continent", hover_name="country", size="pop",
               animation_frame="year", projection="natural earth")
fig.write_html(f'IMG/scatter_geo_gapminder.html',auto_open=True)

# %% [markdown]
# #### table

# %%
import chart_studio.plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")
df.shape
# Out:
# (21, 4)

# %%
table = ff.create_table(df)
table.write_html(f'IMG/plotly_table.html',auto_open=True)

# %% [markdown]
# ### Styling

# %% [markdown]
# - Markers
#   - Alpha blending
#   - Colors
#   - Symbols
#   - Stroke and span
#   - Size

# %% [markdown]
# - Lines
#   - Linetypes
#   - Segments
#     - Slopegraph
#     - Dumbell
#     - Candlestick
#   - Density plots
#   - Parallel Coordinates

# %% [markdown]
# - Polygons
#   - Ribbons

# %% [markdown]
# - Maps
#   - Integrated Maps
#     - Mapbox
#     - geo
#   - Choropleths
#     - Choroplethmapbox
#     - Choropleth
#   - Cartograms
#   - Simple Feature

# %% [markdown]
# - Bars & histograms

# %% [markdown]
# - Boxplots

# %% [markdown]
# ### Subplot

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Make figure with subplots
fig = make_subplots(rows=1, cols=2, specs=[[{"type": "bar"},
                                            {"type": "surface"}]])

# Add bar traces to subplot (1, 1)
fig.add_trace(go.Bar(y=[2, 1, 3]), row=1, col=1)
fig.add_trace(go.Bar(y=[3, 2, 1]), row=1, col=1)
fig.add_trace(go.Bar(y=[2.5, 2.5, 3.5]), row=1, col=1)

# Add surface trace to subplot (1, 2)
# Read data from a csv
z_data = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv")
fig.add_surface(z=z_data)

# Hide legend
fig.update_layout(
    showlegend=False,
    title_text="Default Theme",
    height=500,
    width=800,
)

fig.write_html(f'IMG/plotly_subplot_zdata.html',auto_open=True)

# %% [markdown]
# ## Bubble Plot

# %%
name='IMG/Plotly_Bubble.html'
s = pd.Series(np.random.randint(10,100, 6), index=pd.date_range('2013', periods=6, freq='12M'))
s.to_numpy()
# Out:
# array([75, 25, 61, 96, 55, 73])

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
                x=list(range(6)), 
                y=np.random.randint(1,10, 6),
                text=s.index.astype(str).to_numpy(),
                mode = 'markers',
                marker=dict(
                size=s.to_numpy()))
             )

fig.write_html(name,auto_open=True)

# %% [markdown]
# ## Line PLot

# %%
name='IMG/Plotly_Line1.html'
data = [{
    'x': np.linspace(-1,1,100),
    'y': np.random.randn(100),
    'mode': 'lines',
    'name': 'line plot'
}]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(**data[0]))
fig.write_html(name,auto_open=True)

# %%
name='IMG/Plotly_Lines2.html'
x = np.linspace(-1,1,100)
y = np.random.randn(100)
trace0 = go.Scatter(
    x=x,
    y=y+5,
    mode='lines',
    name='lines',
    connectgaps=True
)
trace1 = go.Scatter(
    x=x,
    y=y,
    mode='lines+markers',
    name='lines+markers'
)
trace2 = go.Scatter(
    x=x,
    y=y-5,
    mode='markers',
    name='markers'
)
data = [trace0, trace1, trace2]

# %%
fig = go.Figure()
fig.add_traces(data)
fig.write_html(name,auto_open=True)

# %% [markdown]
# ## Area Plot

# %%
name='IMG/Plotly_Area.html'
x = np.linspace(-1,1,10)
y0 = np.random.randn(10)
y1 = np.random.randn(10)
trace0 = go.Scatter(
    x=x,
    y=y0,
    mode='none',
    name='tozeroy',
    fill='tozeroy'
)
trace1 = go.Scatter(
    x=x,
    y=y1,
    mode='none',
    name='tonexty',
    fill='tonexty'
)
data = [trace0, trace1]

# %%
fig = go.Figure()
fig.add_traces(data)
fig.write_html(name,auto_open=True)

# %%
name='IMG/Plotly_AreaStacked.html'
x = np.linspace(-1,1,10)
y0 = np.random.rand(10)
y1 = np.random.rand(10)
y2 = np.random.rand(10)
trace0 = go.Scatter(
    x=x,
    y=y0,
    mode='lines',
    name='y0',
    stackgroup='one'
)
trace1 = go.Scatter(
    x=x,
    y=y1,
    mode='lines',
    name='y1',
    stackgroup='one'
)
trace2 = go.Scatter(
    x=x,
    y=y2,
    mode='lines',
    name='y2',
    stackgroup='one'
)
data = [trace0, trace1, trace2]

# %%
fig = go.Figure()
fig.add_traces(data)
fig.write_html(name,auto_open=True)

# %% [markdown]
# ## Bar Plot

# %%
name='IMG/Plotly_Bar.html'
s = pd.Series(np.random.randint(10,100, 6), index=pd.date_range('2013', periods=6, freq='12M'))
trace0 = go.Bar(
    x=s.index,
    y=s,
    name='bar'
)

data = [trace0]

# %%
fig = go.Figure()
fig.add_traces(data)
fig.write_html(name,auto_open=True)

# %% [markdown]
# - Bar Group

# %%
name='IMG/Plotly_Bargroup.html'
df = pd.DataFrame(np.random.randint(10,100, (6,4)), 
                  index=pd.date_range('2013', periods=6, freq='12M'), 
                  columns=['Q1', 'Q2', 'Q3', 'Q4'])


data = [go.Bar(x=df.index, y=df[name], name=name) for name in df.columns]
layout = go.Layout(barmode='group')
fig = go.Figure(data=data, layout=layout)
fig.write_html(name,auto_open=True)

# %% [markdown]
# - Bar Stacked

# %%
name='IMG/Plotly_BarStracked.html'
df = pd.DataFrame(np.random.randint(10,100, (6,4)), 
                  index=pd.date_range('2013', periods=6, freq='12M'), 
                  columns=['Q1', 'Q2', 'Q3', 'Q4'])


data = [go.Bar(x=df.index, y=df[name], name=name) for name in df.columns]
layout = go.Layout(barmode='stack')
fig = go.Figure(data=data, layout=layout)
fig.write_html(name,auto_open=True)

# %% [markdown]
# - Horizontal Bar

# %%
name='IMG/Plotly_BarHorizontal.html'
s = pd.Series(np.random.randint(10,100, 6), index=pd.date_range('2013', periods=6, freq='12M'))
trace0 = go.Bar(
    x=s,
    y=s.index,
    name='horizontal bar',
    orientation='h'
)

data = [trace0]

# %%
fig = go.Figure(data=data, layout=layout)
fig.write_html(name,auto_open=True)

# %% [markdown]
# ## Pie Chart

# %%
name='IMG/Plotly_Pie.html'
s = pd.Series(np.random.randint(10,100, 6), index=pd.date_range('2013', periods=6, freq='12M'))
years = [d.year for d in  s.index.date]
trace0 = go.Pie(
    labels=years,
    values=s,
    name='Pie Chart'
)

data = [trace0]

# %%
fig = go.Figure(data=data, layout=layout)
fig.write_html(name,auto_open=True)

# %% [markdown]
# ## Radar Plot

# %%
name='IMG/Plotly_Radar.html'
s = pd.Series(np.random.randint(10,100, 6), index=[f'Domain-{i}' for i in 'ABCDEF' ])
trace0 = go.Scatterpolar(
    r=[*s, s[0]],
    theta=[*s.index, s.index[0]],
    fill='toself',
    name='Rader Chart'
)

data = [trace0]

layout=go.Layout(
polar=dict(radialaxis=dict(visible=True, range=[0,100])),
showlegend=False
)

# %%
fig = go.Figure(data=data, layout=layout)
fig.write_html(name,auto_open=True)

# %% [markdown]
# - Radar Group

# %%
name='IMG/Plotly_RadarGroup.html'
df = pd.DataFrame(np.random.randint(10,100, (6, 2)), index=[f'Domain-{i}' for i in 'ABCDEF'], columns=['G1', 'G2'])


data = [go.Scatterpolar(r=[*df[name], df[name][0]], theta=[*df.index, df.index[0]], name=name, fill='toself') for name in df.columns]


layout=go.Layout(
polar=dict(radialaxis=dict(visible=True, range=[0,100])),
showlegend=True
)

# %%
fig = go.Figure(data=data, layout=layout)
fig = go.Figure(data=data, layout=layout)
fig.write_html(name,auto_open=True)

# %% [markdown]
# # Pandas with Dash

# %% [markdown]
# >
# >  ```bash
# >    conda install -c conda-forge dash dash-daq
# >    conda install -c conda-forge jupyterlab-dash
# >    jupyter labextension install jupyterlab-dash
# >    conda install -c plotly dash-html-components dash-core-components dash-table
# >  ```
