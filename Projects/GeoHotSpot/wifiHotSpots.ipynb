# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import dash_table as dt
import pandas as pd

from plotly import graph_objs as go
from plotly.graph_objs import *
from dash.dependencies import Input, Output, State

# %%
app = dash.Dash(__name__)
server = app.server
app.title = 'NYC Wi-Fi Hotspots'

app.run_server(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.
# Exception on /favicon.ico [GET]
# Traceback (most recent call last):
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1944, in full_dispatch_request
#     self.try_trigger_before_first_request_functions()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\flask\app.py", line 1992, in try_trigger_before_first_request_functions
#     func()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1318, in _setup_server
#     self._validate_layout()
#   File "C:\Users\hpzju\Anaconda3\envs\ds\lib\site-packages\dash\dash.py", line 1295, in _validate_layout
#     'The layout was `None` '
# dash.exceptions.NoLayoutException: The layout was `None` at the time that `run_server` was called. Make sure to set the `layout` attribute of your application before running the server.

# %%
# -*- coding: utf-8 -*-
